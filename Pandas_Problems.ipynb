# %% [markdown]
# <a href="https://colab.research.google.com/github/AnalystHarpal007/Python_Tutorial/blob/main/Pandas_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets start Solving**

# %%
#import dependencies

import pandas as pd
import xlrd
import openpyxl

# %% [markdown]
# # **Problems for employees dataset**

# %% [markdown]
# Q.1.Filter the DataFrame to show only employees who work in the "IT" department

# %%
df_emp = pd.read_csv('emp_data.csv')
df_emp
# Out:
#     Unnamed: 0         Full Name   Department  Age
# 0            0            Kai Le  Engineering   47
# 1            1      Robert Patel        Sales   58
# 2            2        Cameron Lo           IT   34
# 3            3   Harper Castillo           IT   39
# 4            4           Jade Hu   Accounting   58
# 5            5       Miles Chang      Finance   62
# 6            6     Gianna Holmes           IT   38
# 7            7    Jameson Thomas      Finance   52
# 8            8      Jameson Pena           IT   49
# 9            9          Bella Wu      Finance   63
# 10          10         Jose Wong           IT   45
# 11          11  Lucas Richardson    Marketing   36
# 12          12       Jacob Moore    Marketing   42
# 13          13           Luna Lu           IT   62
# 14          14        Bella Tran  Engineering   45
# 15          15          Ivy Chau        Sales   61
# 16          16      Jordan Kumar           IT   29
# ...

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21 non-null     int64
#  1   Full Name   21 non-null     object
#  2   Department  21 non-null     object
#  3   Age         21 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 804.0+ bytes

# %%
df_emp[df_emp['Department']=='IT']
# Out:
#     Unnamed: 0        Full Name Department  Age
# 2            2       Cameron Lo         IT   34
# 3            3  Harper Castillo         IT   39
# 6            6    Gianna Holmes         IT   38
# 8            8     Jameson Pena         IT   49
# 10          10        Jose Wong         IT   45
# 13          13          Luna Lu         IT   62
# 16          16     Jordan Kumar         IT   29
# 19          19    Lillian Lewis         IT   43

# %% [markdown]
# Q.2.Filter the DataFrame to show only female employees who are older than 50.

# %%
emp_df2 = pd.read_csv('employee.csv')
emp_df2
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 11  E02013          Bella Wu                     NaN      Finance  Female
# ...

# %%
emp_df2.info()
emp_df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          23 non-null     object
#  1   Full Name   21 non-null     object
#  2   Job Title   18 non-null     object
#  3   Department  21 non-null     object
#  4   Gender      21 non-null     object
#  5   Age         21 non-null     float64
#  6   Hire Date   14 non-null     object
#  7   Salary      21 non-null     object
#  8   Country     17 non-null     object
#  9   City        23 non-null     object
#  10  Exit Date   2 non-null      object
# dtypes: float64(1), object(10)
# memory usage: 2.1+ KB
# (23, 11)

# %%
emp_df2.head()
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
#
#     Hire Date    Salary        Country      City Exit Date
# 0    02/05/22  $92,368   United States  Columbus       NaN
# 1  10/23/2013  $45,703   United States   Chicago       NaN
# 2   3/24/2019  $83,576           China  Shanghai       NaN
# 3    04/07/18  $98,062   United States   Seattle       NaN
# 4         NaN       NaN            NaN    Austin       NaN

# %%
emp_df2[(emp_df2['Gender']=='Female') & (emp_df2['Age']>50)]
# Out:
#         ID         Full Name             Job Title  Department  Gender   Age  \
# 6   E02008           Jade Hu           Sr. Analyst  Accounting  Female  58.0
# 11  E02013          Bella Wu                   NaN     Finance  Female  63.0
# 15  E02017           Luna Lu  IT Systems Architect          IT  Female  62.0
# 17  E02019          Ivy Chau               Analyst       Sales  Female  61.0
# 19  E02021  Sophia Gutierrez               Manager  Accounting  Female  63.0
#
#     Hire Date     Salary        Country       City Exit Date
# 6   6/27/2009   $89,744           China  Chongqing       NaN
# 11        NaN   $71,418             NaN    Phoenix       NaN
# 15        NaN   $64,208   United States      Miami       NaN
# 17        NaN   $54,811           China  Chongqing       NaN
# 19   02/08/09  $102,649   United States     Austin       NaN

# %% [markdown]
# Q.3.Sort the DataFrame by the "Age" column in descending order.

# %%
emp_df2.sort_values(by='Age',ascending=False)
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 11  E02013          Bella Wu                     NaN      Finance  Female
# 19  E02021  Sophia Gutierrez                 Manager   Accounting  Female
# 15  E02017           Luna Lu    IT Systems Architect           IT  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 17  E02019          Ivy Chau                 Analyst        Sales  Female
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 16  E02018        Bella Tran          Vice President  Engineering  Female
# 20  E02022          Eli Dang             Sr. Manager   Accounting    Male
# ...

# %% [markdown]
# Q.4.Sort the DataFrame first by "Department" (ascending) and then by "Age" (descending).

# %%
emp_df2.sort_values(by=['Department','Age'],ascending=[True,False])
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 19  E02021  Sophia Gutierrez                 Manager   Accounting  Female
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 20  E02022          Eli Dang             Sr. Manager   Accounting    Male
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 16  E02018        Bella Tran          Vice President  Engineering  Female
# 11  E02013          Bella Wu                     NaN      Finance  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 15  E02017           Luna Lu    IT Systems Architect           IT  Female
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 12  E02014         Jose Wong                     NaN           IT    Male
# 21  E02023     Lillian Lewis     Technical Architect           IT  Female
# ...

# %% [markdown]
# Q.5.Set the "ID" column as the index of the DataFrame and display the first 5 rows.

# %%
emp_df2.iloc[0:5]
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
#
#     Hire Date    Salary        Country      City Exit Date
# 0    02/05/22  $92,368   United States  Columbus       NaN
# 1  10/23/2013  $45,703   United States   Chicago       NaN
# 2   3/24/2019  $83,576           China  Shanghai       NaN
# 3    04/07/18  $98,062   United States   Seattle       NaN
# 4         NaN       NaN            NaN    Austin       NaN

# %%
new_df = emp_df2.set_index('ID')
new_df
# Out:
#                Full Name               Job Title   Department  Gender   Age  \
# ID
# E02002            Kai Le       Controls Engineer  Engineering    Male  47.0
# E02003      Robert Patel                 Analyst        Sales    Male  58.0
# E02004        Cameron Lo   Network Administrator           IT    Male  34.0
# E02005   Harper Castillo    IT Systems Architect           IT  Female  39.0
# E02006               NaN                     NaN          NaN     NaN   NaN
# E02007               NaN                     NaN          NaN     NaN   NaN
# E02008           Jade Hu             Sr. Analyst   Accounting  Female  58.0
# E02009       Miles Chang              Analyst II      Finance    Male  62.0
# E02010     Gianna Holmes   System Administrator†           IT  Female  38.0
# E02011    Jameson Thomas                 Manager      Finance    Male  52.0
# E02012      Jameson Pena         Systems Analyst           IT    Male  49.0
# ...

# %%
new_df.loc['E02002':'E02006']
# Out:
#               Full Name              Job Title   Department  Gender   Age  \
# ID
# E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# E02003     Robert Patel                Analyst        Sales    Male  58.0
# E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# E02006              NaN                    NaN          NaN     NaN   NaN
#
#          Hire Date    Salary        Country      City Exit Date
# ID
# E02002    02/05/22  $92,368   United States  Columbus       NaN
# E02003  10/23/2013  $45,703   United States   Chicago       NaN
# E02004   3/24/2019  $83,576           China  Shanghai       NaN
# E02005    04/07/18  $98,062   United States   Seattle       NaN
# E02006         NaN       NaN            NaN    Austin       NaN

# %%
new_df.head()
# Out:
#               Full Name              Job Title   Department  Gender   Age  \
# ID
# E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# E02003     Robert Patel                Analyst        Sales    Male  58.0
# E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# E02006              NaN                    NaN          NaN     NaN   NaN
#
#          Hire Date    Salary        Country      City Exit Date
# ID
# E02002    02/05/22  $92,368   United States  Columbus       NaN
# E02003  10/23/2013  $45,703   United States   Chicago       NaN
# E02004   3/24/2019  $83,576           China  Shanghai       NaN
# E02005    04/07/18  $98,062   United States   Seattle       NaN
# E02006         NaN       NaN            NaN    Austin       NaN

# %% [markdown]
# Q.6.Select the "Full Name" and "Job Title" columns for the employee with the ID "E02011".

# %%
emp_df2
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 11  E02013          Bella Wu                     NaN      Finance  Female
# ...

# %%
emp_df2[emp_df2['ID'] =='E02011'][['Full Name','Job Title']]
# Out:
#         Full Name Job Title
# 9  Jameson Thomas   Manager

# %%
df1 = emp_df2[emp_df2['ID'] =='E02011'] #Another way
df1[['Full Name','Job Title']]
# Out:
#         Full Name Job Title
# 9  Jameson Thomas   Manager

# %% [markdown]
# Q.7. Export the DataFrame to a new CSV file named "employee_data.csv".

# %%
df1[['Full Name','Job Title']].to_csv('employee_data.csv')

# %% [markdown]
# Q.8.Export the DataFrame to an Excel file named "employee_data.xlsx"

# %%
#emp_df2.head()
emp_df2.to_excel('employee_data.xlsx')

# %% [markdown]
# Q.9.Use df.info to display information about the DataFrame, including the number of non-null entries in each column.

# %%
emp_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          23 non-null     object
#  1   Full Name   21 non-null     object
#  2   Job Title   18 non-null     object
#  3   Department  21 non-null     object
#  4   Gender      21 non-null     object
#  5   Age         21 non-null     float64
#  6   Hire Date   14 non-null     object
#  7   Salary      21 non-null     object
#  8   Country     17 non-null     object
#  9   City        23 non-null     object
#  10  Exit Date   2 non-null      object
# dtypes: float64(1), object(10)
# memory usage: 2.1+ KB

# %% [markdown]
#   Q.10.Use the head() function to display the first 10 rows of the DataFrame and tail() to display the last 5 rows.

# %%
emp_df2.head(10)
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
# 5  E02007              NaN                    NaN          NaN     NaN   NaN
# 6  E02008          Jade Hu            Sr. Analyst   Accounting  Female  58.0
# 7  E02009      Miles Chang             Analyst II      Finance    Male  62.0
# 8  E02010    Gianna Holmes  System Administrator†           IT  Female  38.0
# 9  E02011   Jameson Thomas                Manager      Finance    Male  52.0
#
#     Hire Date     Salary        Country       City  Exit Date
# ...

# %%
emp_df2.tail(5)
# Out:
#         ID         Full Name               Job Title  Department  Gender  \
# 18  E02020      Jordan Kumar    Service Desk Analyst          IT    Male
# 19  E02021  Sophia Gutierrez                 Manager  Accounting  Female
# 20  E02022          Eli Dang             Sr. Manager  Accounting    Male
# 21  E02023     Lillian Lewis     Technical Architect          IT  Female
# 22  E02024      Serenity Cao  Account Representative       Sales  Female
#
#      Age   Hire Date     Salary        Country      City  Exit Date
# 18  29.0    11/11/17   $95,729   United States   Seattle        NaN
# 19  63.0    02/08/09  $102,649   United States    Austin        NaN
# 20  45.0  11/16/2015  $122,875   United States   Chicago        NaN
# 21  43.0   8/14/2013   $83,323   United States   Phoenix  3/31/2019
# 22  31.0  10/21/2018   $66,721           China  Shanghai        NaN

# %% [markdown]
# # **Problems - Walmart excel dataset**

# %%
import pandas as pd
import xlrd
import openpyxl

# %% [markdown]
# Q.1.Filter the DataFrame to show only transactions where the customer type is "Member".

# %%
wal_df = pd.read_excel('/walmart_data.xlsx')
wal_df
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 0   750-67-8428      D      San Jose        Member   40  Female
# 1   226-31-3081      A  Philadelphia        Normal   29  Female
# 2   631-41-3108      A       Phoenix        Normal   28    Male
# 3   123-19-1176      B      New York        Member   27    Male
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 6   355-53-5943      C   Los Angeles        Member   34  Female
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 8   665-32-9167      A      New York        Member   66  Female
# 9   692-92-5582      A  Philadelphia        Member   56  Female
# 10  351-62-0822      D       Chicago        Member   60  Female
# 11  529-56-3974      A        Dallas        Member   46    Male
# 12  365-64-0515      C      New York        Normal   55  Female
# 13  252-56-2699      B       Chicago        Normal   35    Male
# ...

# %%
wal_df.head()
# Out:
#     invoice_id branch          city customer_type  age  gender  \
# 0  750-67-8428      D      San Jose        Member   40  Female
# 1  226-31-3081      A  Philadelphia        Normal   29  Female
# 2  631-41-3108      A       Phoenix        Normal   28    Male
# 3  123-19-1176      B      New York        Member   27    Male
# 4  373-73-7910      A       Chicago        Normal   52    Male
#
#              product_line  unit_price     total       date payment_method  \
# 0       Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 1  Electronic accessories       15.28   80.2200 2019-03-08           Cash
# 2      Home and lifestyle       46.33  340.5255 2019-03-03    Credit card
# 3       Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 4       Sports and travel       86.31  634.3785 2019-02-08        Ewallet
#
#    rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
wal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      19 non-null     object
#  1   branch          19 non-null     object
#  2   city            19 non-null     object
#  3   customer_type   19 non-null     object
#  4   age             19 non-null     int64
#  5   gender          19 non-null     object
#  6   product_line    19 non-null     object
#  7   unit_price      19 non-null     float64
#  8   total           19 non-null     float64
#  9   date            19 non-null     datetime64[ns]
#  10  payment_method  19 non-null     object
#  11  rating          19 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(7)
# memory usage: 1.9+ KB

# %%
wal_df[wal_df['customer_type']=='Member']
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 0   750-67-8428      D      San Jose        Member   40  Female
# 3   123-19-1176      B      New York        Member   27    Male
# 6   355-53-5943      C   Los Angeles        Member   34  Female
# 8   665-32-9167      A      New York        Member   66  Female
# 9   692-92-5582      A  Philadelphia        Member   56  Female
# 10  351-62-0822      D       Chicago        Member   60  Female
# 11  529-56-3974      A        Dallas        Member   46    Male
# 15  299-46-1805      B      New York        Member   39  Female
# 16  656-95-9349      B   Los Angeles        Member   46  Female
#
#               product_line  unit_price     total       date payment_method  \
# 0        Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 3        Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 6   Electronic accessories       68.84  433.6920 2019-02-25        Ewallet
# ...

# %% [markdown]
# Q.2.Filter the DataFrame to show transactions where the total amount is greater than $500.

# %%
#wal_df.head()
wal_df[wal_df['total']>500]
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 0   750-67-8428      D      San Jose        Member   40  Female
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 14  829-34-3910      C     San Diego        Normal   24  Female
# 15  299-46-1805      B      New York        Member   39  Female
# 16  656-95-9349      B   Los Angeles        Member   46  Female
#
#               product_line  unit_price     total       date payment_method  \
# 0        Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 5   Electronic accessories       85.39  627.6165 2019-03-25        Ewallet
# 7       Home and lifestyle       73.56  772.3800 2019-02-24        Ewallet
# 14       Health and beauty       71.38  749.4900 2019-03-29           Cash
# ...

# %%
wal_df[(wal_df['total']>500) & (wal_df['customer_type']=='Member')]
# Out:
#      invoice_id branch         city customer_type  age  gender  \
# 0   750-67-8428      D     San Jose        Member   40  Female
# 15  299-46-1805      B     New York        Member   39  Female
# 16  656-95-9349      B  Los Angeles        Member   46  Female
#
#          product_line  unit_price     total       date payment_method  rating
# 0   Health and beauty       74.69  548.9715 2019-01-05        Ewallet     9.1
# 15  Sports and travel       93.72  590.4360 2019-01-15           Cash     4.5
# 16  Health and beauty       68.93  506.6355 2019-03-11    Credit card     4.6

# %% [markdown]
# Q.3.Sort the DataFrame by the "total" column in descending order to find the highest transactions.

# %%
wal_df.sort_values(by='total',ascending=False).head()
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 14  829-34-3910      C     San Diego        Normal   24  Female
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 15  299-46-1805      B      New York        Member   39  Female
#
#               product_line  unit_price     total       date payment_method  \
# 7       Home and lifestyle       73.56  772.3800 2019-02-24        Ewallet
# 14       Health and beauty       71.38  749.4900 2019-03-29           Cash
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 5   Electronic accessories       85.39  627.6165 2019-03-25        Ewallet
# 15       Sports and travel       93.72  590.4360 2019-01-15           Cash
#
#     rating
# 7      8.0
# 14     5.7
# 4      5.3
# 5      4.1
# 15     4.5

# %% [markdown]
# Q.4.Sort the DataFrame first by "branch" (ascending) and then by "unit_price" (descending).

# %%
wal_df.sort_values(by=['branch','unit_price'],ascending=[True,False]).head()
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 9   692-92-5582      A  Philadelphia        Member   56  Female
# 2   631-41-3108      A       Phoenix        Normal   28    Male
# 8   665-32-9167      A      New York        Member   66  Female
# 11  529-56-3974      A        Dallas        Member   46    Male
#
#               product_line  unit_price     total       date payment_method  \
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 9       Food and beverages       54.84  172.7460 2019-02-20    Credit card
# 2       Home and lifestyle       46.33  340.5255 2019-03-03    Credit card
# 8        Health and beauty       36.26   76.1460 2019-01-10    Credit card
# 11  Electronic accessories       25.51  107.1420 2019-03-09           Cash
#
#     rating
# 4      5.3
# 9      5.9
# 2      7.4
# 8      7.2
# 11     6.8

# %% [markdown]
# Q.5.Set the "invoice_id" column as the index of the DataFrame and display the first 5 rows.

# %%
wal_df.iloc[0:5]
# Out:
#     invoice_id branch          city customer_type  age  gender  \
# 0  750-67-8428      D      San Jose        Member   40  Female
# 1  226-31-3081      A  Philadelphia        Normal   29  Female
# 2  631-41-3108      A       Phoenix        Normal   28    Male
# 3  123-19-1176      B      New York        Member   27    Male
# 4  373-73-7910      A       Chicago        Normal   52    Male
#
#              product_line  unit_price     total       date payment_method  \
# 0       Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 1  Electronic accessories       15.28   80.2200 2019-03-08           Cash
# 2      Home and lifestyle       46.33  340.5255 2019-03-03    Credit card
# 3       Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 4       Sports and travel       86.31  634.3785 2019-02-08        Ewallet
#
#    rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
wal_df.set_index('invoice_id').head()
# Out:
#             branch          city customer_type  age  gender  \
# invoice_id
# 750-67-8428      D      San Jose        Member   40  Female
# 226-31-3081      A  Philadelphia        Normal   29  Female
# 631-41-3108      A       Phoenix        Normal   28    Male
# 123-19-1176      B      New York        Member   27    Male
# 373-73-7910      A       Chicago        Normal   52    Male
#
#                        product_line  unit_price     total       date  \
# invoice_id
# 750-67-8428       Health and beauty       74.69  548.9715 2019-01-05
# 226-31-3081  Electronic accessories       15.28   80.2200 2019-03-08
# 631-41-3108      Home and lifestyle       46.33  340.5255 2019-03-03
# 123-19-1176       Health and beauty       58.22  489.0480 2019-01-27
# 373-73-7910       Sports and travel       86.31  634.3785 2019-02-08
#
#             payment_method  rating
# invoice_id
# 750-67-8428        Ewallet     9.1
# 226-31-3081           Cash     9.6
# 631-41-3108    Credit card     7.4
# ...

# %% [markdown]
# Q.6.Select the "city" and "product_line" columns for transactions where the payment method is "Ewallet".

# %%
#wal_df.head()

wal_pay = wal_df[wal_df['payment_method']=='Ewallet'][['payment_method','city','product_line']]
wal_pay
# Out:
#    payment_method          city            product_line
# 0         Ewallet      San Jose       Health and beauty
# 3         Ewallet      New York       Health and beauty
# 4         Ewallet       Chicago       Sports and travel
# 5         Ewallet  Philadelphia  Electronic accessories
# 6         Ewallet   Los Angeles  Electronic accessories
# 7         Ewallet  Philadelphia      Home and lifestyle
# 10        Ewallet       Chicago     Fashion accessories
# 12        Ewallet      New York  Electronic accessories
# 13        Ewallet       Chicago      Food and beverages

# %% [markdown]
# Q.7. Export the DataFrame to a new CSV file named "invoice_data.csv".

# %%
wal_pay.to_csv('invoice_data.csv')

# %%
#wal_df.head()
wal_df[['invoice_id','branch','city','total','date','payment_method']].to_csv('invoices_data.csv',sep=',', index=None)

# %% [markdown]
# Q.8.Export the DataFrame to an Excel file named "invoice_data.xlsx".

# %%
wal_pay.to_excel('invoice_data.xlsx')

# %%
#wal_df.head()
wal_df[['invoice_id','branch','city','total','date','payment_method']].to_excel('invoiced_data.xlsx', index=None, header=None)

# %% [markdown]
# Q.9.Use df.info to display information about the DataFrame, including the number of non-null entries in each column

# %%
wal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      19 non-null     object
#  1   branch          19 non-null     object
#  2   city            19 non-null     object
#  3   customer_type   19 non-null     object
#  4   age             19 non-null     int64
#  5   gender          19 non-null     object
#  6   product_line    19 non-null     object
#  7   unit_price      19 non-null     float64
#  8   total           19 non-null     float64
#  9   date            19 non-null     datetime64[ns]
#  10  payment_method  19 non-null     object
#  11  rating          19 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(7)
# memory usage: 1.9+ KB

# %% [markdown]
# Q.10.Use the head() function to display the first 10 rows of the DataFrame and tail() to display the last 5 rows.

# %%
wal_df.head(10)
# Out:
#     invoice_id branch          city customer_type  age  gender  \
# 0  750-67-8428      D      San Jose        Member   40  Female
# 1  226-31-3081      A  Philadelphia        Normal   29  Female
# 2  631-41-3108      A       Phoenix        Normal   28    Male
# 3  123-19-1176      B      New York        Member   27    Male
# 4  373-73-7910      A       Chicago        Normal   52    Male
# 5  699-14-3026      B  Philadelphia        Normal   54    Male
# 6  355-53-5943      C   Los Angeles        Member   34  Female
# 7  315-22-5665      D  Philadelphia        Normal   33  Female
# 8  665-32-9167      A      New York        Member   66  Female
# 9  692-92-5582      A  Philadelphia        Member   56  Female
#
#              product_line  unit_price     total       date payment_method  \
# 0       Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 1  Electronic accessories       15.28   80.2200 2019-03-08           Cash
# ...

# %%
wal_df.tail(5)
# Out:
#      invoice_id branch         city customer_type  age  gender  \
# 14  829-34-3910      C    San Diego        Normal   24  Female
# 15  299-46-1805      B     New York        Member   39  Female
# 16  656-95-9349      B  Los Angeles        Member   46  Female
# 17  765-26-6951      C      Houston        Normal   33    Male
# 18  329-62-1586      C      Phoenix        Normal   54    Male
#
#           product_line  unit_price     total       date payment_method  rating
# 14   Health and beauty       71.38  749.4900 2019-03-29           Cash     5.7
# 15   Sports and travel       93.72  590.4360 2019-01-15           Cash     4.5
# 16   Health and beauty       68.93  506.6355 2019-03-11    Credit card     4.6
# 17   Sports and travel       72.61  457.4430 2019-01-01    Credit card     6.9
# 18  Food and beverages       54.67  172.2105 2019-01-21    Credit card     8.6

# %%
# importing excel file without header
df_id = pd.read_excel('invoiced_data.xlsx',header=None,names=['id','branch','city','total','date','payment_method'])
df_id
# Out:
#              id branch          city     total       date payment_method
# 0   750-67-8428      D      San Jose  548.9715 2019-01-05        Ewallet
# 1   226-31-3081      A  Philadelphia   80.2200 2019-03-08           Cash
# 2   631-41-3108      A       Phoenix  340.5255 2019-03-03    Credit card
# 3   123-19-1176      B      New York  489.0480 2019-01-27        Ewallet
# 4   373-73-7910      A       Chicago  634.3785 2019-02-08        Ewallet
# 5   699-14-3026      B  Philadelphia  627.6165 2019-03-25        Ewallet
# 6   355-53-5943      C   Los Angeles  433.6920 2019-02-25        Ewallet
# 7   315-22-5665      D  Philadelphia  772.3800 2019-02-24        Ewallet
# 8   665-32-9167      A      New York   76.1460 2019-01-10    Credit card
# 9   692-92-5582      A  Philadelphia  172.7460 2019-02-20    Credit card
# 10  351-62-0822      D       Chicago   60.8160 2019-02-06        Ewallet
# 11  529-56-3974      A        Dallas  107.1420 2019-03-09           Cash
# ...
